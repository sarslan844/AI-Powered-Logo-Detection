# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/logo detection.v2i.yolov11.zip" -d "/content/logo_dataset"
# Out:
# Archive:  /content/drive/MyDrive/logo detection.v2i.yolov11.zip
#  extracting: /content/logo_dataset/test/images/frame_145_jpg.rf.2ddf1e6ab2470948715c10d6241edd99.jpg
#  extracting: /content/logo_dataset/train/images/frame_090_jpg.rf.469130db1675caf643b77e287f695618.jpg
#  extracting: /content/logo_dataset/test/images/frame_095_jpg.rf.4c82b41ddd675ccc4048399b84c9cb79.jpg
#  extracting: /content/logo_dataset/test/images/frame_016_jpg.rf.31242e165079d0e66a2365c581fc6b4a.jpg
#  extracting: /content/logo_dataset/test/images/frame_164_jpg.rf.bbf08bdcddf297e83268d936b6ea216a.jpg
#  extracting: /content/logo_dataset/test/images/frame_101_jpg.rf.65d59a9568bb9324a3c8ae3563c8ff1d.jpg
#  extracting: /content/logo_dataset/test/images/frame_040_jpg.rf.4c610fc18069f68d8fadbdf7f944ec8e.jpg
#  extracting: /content/logo_dataset/test/images/frame_184_jpg.rf.025b33946b286dbcfce38aec83205b6f.jpg
#  extracting: /content/logo_dataset/train/images/frame_072_jpg.rf.006f6ac8c28121d82dd8c49ca0917393.jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/YOLO_Models/best.pt")

metrics = model.val(
    data="/content/logo_dataset/data.yaml"
)
# Out:
# Ultralytics 8.4.89 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 974.0±225.1 MB/s, size: 51.2 KB)
# val: Scanning /content/logo_dataset/valid/labels... 49 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 49/49 898.1it/s 0.1s
# val: New cache created: /content/logo_dataset/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all         49         49      0.998          1      0.995      0.887
# Speed: 10.5ms preprocess, 11.0ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /content/runs/detect/val-3

# %%
# !ls "/content/runs/detect/val-3"
# Out:
# BoxF1_curve.png  confusion_matrix_normalized.png  val_batch1_labels.jpg
# BoxP_curve.png	 confusion_matrix.png		  val_batch1_pred.jpg
# BoxPR_curve.png  val_batch0_labels.jpg		  val_batch2_labels.jpg
# BoxR_curve.png	 val_batch0_pred.jpg		  val_batch2_pred.jpg

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/YOLO_Models/best.pt")

model.predict(
    source="/content/logo_dataset/test/images",
    save=True,
    conf=0.25
)
# Out:
# image 1/25 /content/logo_dataset/test/images/frame_012_jpg.rf.4692f08046ca0710f293972b81105d2e.jpg: 640x640 1 PAF, 13.3ms
# image 2/25 /content/logo_dataset/test/images/frame_014_jpg.rf.30ad529bdd8cbe95f35d279f817908c9.jpg: 640x640 1 PAF, 13.4ms
# image 3/25 /content/logo_dataset/test/images/frame_016_jpg.rf.31242e165079d0e66a2365c581fc6b4a.jpg: 640x640 1 PAF, 10.9ms
# image 4/25 /content/logo_dataset/test/images/frame_018_jpg.rf.f30d9d43cf16f19c09363d87b546cd5c.jpg: 640x640 1 PAF, 11.9ms
# image 5/25 /content/logo_dataset/test/images/frame_024_jpg.rf.23196622491b7104499c6270daa1e61c.jpg: 640x640 1 PAF, 14.8ms
# image 6/25 /content/logo_dataset/test/images/frame_025_jpg.rf.e8a02693773e3913e89d87f70df4e238.jpg: 640x640 1 PAF, 9.9ms
# image 7/25 /content/logo_dataset/test/images/frame_029_jpg.rf.c5d0ec1117af855a9c1a095ac7d3d646.jpg: 640x640 1 PAF, 9.8ms
# image 8/25 /content/logo_dataset/test/images/frame_040_jpg.rf.4c610fc18069f68d8fadbdf7f944ec8e.jpg: 640x640 1 PAF, 9.3ms
# ...

# %%
# !ls "/content/runs/detect/predict"
# Out:
# frame_012_jpg.rf.4692f08046ca0710f293972b81105d2e.jpg
# frame_014_jpg.rf.30ad529bdd8cbe95f35d279f817908c9.jpg
# frame_016_jpg.rf.31242e165079d0e66a2365c581fc6b4a.jpg
# frame_018_jpg.rf.f30d9d43cf16f19c09363d87b546cd5c.jpg
# frame_024_jpg.rf.23196622491b7104499c6270daa1e61c.jpg
# frame_025_jpg.rf.e8a02693773e3913e89d87f70df4e238.jpg
# frame_029_jpg.rf.c5d0ec1117af855a9c1a095ac7d3d646.jpg
# frame_040_jpg.rf.4c610fc18069f68d8fadbdf7f944ec8e.jpg
# frame_057_jpg.rf.a6e344dc2f38badd8c59df23fd9b350b.jpg
# frame_095_jpg.rf.4c82b41ddd675ccc4048399b84c9cb79.jpg
# frame_101_jpg.rf.65d59a9568bb9324a3c8ae3563c8ff1d.jpg
# frame_102_jpg.rf.cd3ad969b45e56cd2f15db0d3447e071.jpg
# frame_113_jpg.rf.f22c73b03f98e0045779c1072190c725.jpg
# frame_132_jpg.rf.71ba6d20bc1a7f9cc137dfd0c3d4baa1.jpg
# frame_138_jpg.rf.ecf55168267bafb207aa6f7e6117824c.jpg
# frame_145_jpg.rf.2ddf1e6ab2470948715c10d6241edd99.jpg
# frame_163_jpg.rf.995299b6be409b9b30c704be83067596.jpg
# ...
